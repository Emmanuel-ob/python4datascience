# %%
import pandas as pd

jiji_adds = pd.read_csv('jiji_trending_adds.csv')
print(jiji_adds[['title', 'price']])
# Out:
#                                                 title                price
# 0                               Toyota Camry 2010 Red          ₦ 1,500,000
# 1                              Lexus RX 350 2018 Blue         ₦ 20,500,000
# 2                      Lexus GX 460 Luxury 2016 Black         ₦ 27,000,000
# 3                       Acura ZDX Base AWD 2011 Black          ₦ 4,500,000
# 4                     Mercedes-Benz GLA 250 2019 Gray         ₦ 18,700,000
# 5                                   Toyota Camry 2010          ₦ 1,800,000
# 6                            Lexus ES 330 2006 Silver          ₦ 2,599,999
# 7                              Toyota RAV4 2001 Black          ₦ 1,600,000
# 8              Land Rover Range Rover Evoque 2014 Red          ₦ 5,000,000
# 9               Lexus GX 470 Sport Utility 2006 Black          ₦ 9,800,000
# 10                            Nissan Almera 2010 Gray          ₦ 1,280,000
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/IT_Salary_Survey_EU_18-20/Survey_2019.csv')
#display(df.head(10))
display(df['City'].unique())
# Out:
# array(['Berlin', 'Hamburg', 'Frankfurt', 'Munich', 'Cologne',
#        'Düsseldorf', 'Wolfsburg', 'MA', 'Leipzig', 'Nuremberg', 'Krakow',
#        'Prague', 'Wroclaw', 'Stuttgart', 'London', 'Karlsruhe',
#        'Ingolstadt', 'Riga', 'Bern', 'Moscow', 'Darmstadt', 'Dusseldorf',
#        'Kyiv', 'Freiburg', 'Amsterdam', 'Vienna', 'Pforzheim', 'Kassel ',
#        'Madrid', 'Marburg', 'Warsaw', 'Hannover', 'Paris', 'Milan',
#        'Odesa', 'Cork', 'Zug', 'Heidelberg', 'Brussels', 'Bielefeld',
#        'Dublin', 'Jyvaskyla', 'Toulouse', 'Dubai', 'Zurich', 'Lingen',
#        'Dresden', 'Lugano', 'Walldorf', 'Schleswig-Holstein',
#        'Braunschweig', 'Kaiserslautern', 'Eindhoven', 'Saint Petersburg',
#        'Eindhoven ', 'Leeuwarden', 'Hilversum', 'Gdańsk', 'Gothenburg',
#        'Almere', 'Limassol', 'Stockholm', 'Tampere', 'Bayern',
#        'Rotterdam', 'Antwerpen', 'Tallinn', 'Koblenz', 'Würzburg ',
#        'Bremen', 'Lausanne', 'Nizhny Novgorod ', 'Saint-Petersburg ',
# ...

# %%
#Filter by City and Programming language
#display(df[(df['City'] == 'Munich') & (df['Your main technology / programming language'] == 'Python')])

#Filter by city, programming language and job title
#display(df[(df['City'] == 'Munich') & (df['Your main technology / programming language'] == 'Python') & (df["Position (without seniority)"] == 'Data Scientist')])

#derived_df = df[(df['City'] == 'Munich' ) & (df['Your main technology / programming language'] == 'Python') & (df["Position (without seniority)"] == 'Data Scientist')]
derived_df = df[((df['City'] == 'Berlin') | (df['City'] == 'Munich')) & (df['Your main technology / programming language'] == 'Python') & (df["Position (without seniority)"] == 'Data Scientist')]
#display(derived_df)
display(derived_df.describe())
# Out:
#              Age  Years of experience  \
# count  50.000000            64.000000
# mean   30.300000             5.343750
# std     3.221421             3.582226
# min    23.000000             0.000000
# 25%    28.000000             2.000000
# 50%    30.000000             5.000000
# 75%    32.000000             8.000000
# max    39.000000            18.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                        64.000000     44.000000
# mean                                      79407.812500  11143.704545
# std                                       25797.645424  12139.763498
# min                                       40000.000000      0.000000
# 25%                                       58875.000000   2255.750000
# 50%                                       73000.000000   8500.000000
# 75%                                       96000.000000  15250.000000
# ...
